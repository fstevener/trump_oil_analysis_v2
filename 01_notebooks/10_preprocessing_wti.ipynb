# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### CSV-Daten laden

# %% [markdown]
# minütliche WTI Future Intraday Kurse in USD von 2011-2022

# %%
wti = pd.read_csv("C:/Users/02_Florian_Benutzer/Desktop/trump_oil_analysis_v2/00_data\wti.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\02_Florian_Benutzer\AppData\Local\Temp\ipykernel_14136\1190269471.py:1: SyntaxWarning: invalid escape sequence '\w'
#   wti = pd.read_csv("C:/Users/02_Florian_Benutzer/Desktop/trump_oil_analysis_v2/00_data\wti.csv")

# %%
wti.head()
# Out:
#                   time   open   high    low  close
# 0  2011-01-02 20:15:00  91.28  91.29  91.26  91.26
# 1  2011-01-02 20:16:00  91.26  91.26  91.25  91.26
# 2  2011-01-02 20:17:00  91.25  91.26  91.25  91.26
# 3  2011-01-02 20:18:00  91.27  91.27  91.26  91.26
# 4  2011-01-02 20:19:00  91.25  91.25  91.25  91.25

# %%
wti_v1 = wti.copy()

# %% [markdown]
# Zeitzone des Datensatzes bestimmen, da auf Kaggle nicht angegebem

# %%
# Einbruch der counts um 17 Uhr deutet auf NY Zeitzone hin

# Mit diesem Python-Code gruppierst du die Daten nach der Uhrzeit, die aktuell im Datensatz steht, und zählst, wie viele Einträge es pro Stunde gibt:

# Fall 1: Die Lücke ist bei 17 Uhr. -> Deine Daten sind bereits in der New York Zeitzone (EST/EDT).

wti_v1['time'] = pd.to_datetime(wti_v1['time'])

# Stunde extrahieren (0 bis 23)
wti_v1['hour'] = wti_v1['time'].dt.hour

# Anzahl der Datenpunkte pro Stunde zählen
print(wti_v1['hour'].value_counts().sort_index())
# Out:
# hour
# 0     145365
# 1     154919
# 2     171426
# 3     182765
# 4     183397
# 5     182139
# 6     181676
# 7     182371
# 8     184237
# 9     185107
# 10    185036
# 11    185006
# 12    184443
# 13    180690
# 14    176731
# 15    167613
# 16    147228
# 17     19011
# 18    134967
# 19    129162
# 20    158876
# 21    161296
# 22    153402
# 23    146162
# Name: count, dtype: int64

# %%
# Nur Freitage filtern - da Börsenschluss im 17 Uhr - deutet auf NY Zeit hin

# schauen wir uns den letzten Datenpunkt vor dem Wochenende an. Freitags um 17:00 Uhr New York

freitage = wti_v1[wti_v1['time'].dt.dayofweek == 4]

# Die jeweils letzte Uhrzeit an jedem Freitag anzeigen
print(freitage.groupby(freitage['time'].dt.date)['time'].max().head(10))
# Out:
# time
# 2011-01-07   2011-01-07 17:00:00
# 2011-01-14   2011-01-14 16:59:00
# 2011-01-21   2011-01-21 17:00:00
# 2011-01-28   2011-01-28 16:59:00
# 2011-02-04   2011-02-04 16:59:00
# 2011-02-11   2011-02-11 16:59:00
# 2011-02-18   2011-02-18 16:59:00
# 2011-02-25   2011-02-25 16:59:00
# 2011-03-04   2011-03-04 16:59:00
# 2011-03-11   2011-03-11 16:59:00
# Name: time, dtype: datetime64[us]

# %% [markdown]
# Konvertierung in US/East und von da in UTC Timestamps

# %%
wti_v2 = wti.copy()

# %%
# 2. Den String in ein "naives" (zeitzonenloses) Datetime-Objekt umwandeln
# (Pandas erkennt das Format meistens automatisch)
wti_v2['time'] = pd.to_datetime(wti_v2['time'])

# 3. New York Zeit zuweisen (Lokalisieren)
# 'ambiguous='NaT'' fängt die doppelte Stunde bei der Umstellung im Herbst ab,
# 'nonexistent='NaT'' fängt die fehlende Stunde bei der Umstellung im Frühjahr ab.
wti_v2['timestamp_ny'] = wti_v2['time'].dt.tz_localize('America/New_York', ambiguous='NaT', nonexistent='NaT')

# 4. In UTC umrechnen
wti_v2['timestamp_utc'] = wti_v2['timestamp_ny'].dt.tz_convert('UTC')

# 5. (Optional) Wenn du das "+00:00" am Ende der UTC-Zeit nicht in der CSV haben willst,
# kannst du die Zeitzonen-Information wieder entfernen (die Zeit bleibt die von UTC):
wti_v2['timestamp_utc_clean'] = wti_v2['timestamp_utc'].dt.tz_localize(None)

# Ergebnis überprüfen
#print(df[['Timestamp', 'Timestamp_UTC_clean']].head())

# %%
wti_v2
# Out:
#                        time    open    high     low   close  \
# 0       2011-01-02 20:15:00  91.280  91.290  91.260  91.260
# 1       2011-01-02 20:16:00  91.260  91.260  91.250  91.260
# 2       2011-01-02 20:17:00  91.250  91.260  91.250  91.260
# 3       2011-01-02 20:18:00  91.270  91.270  91.260  91.260
# 4       2011-01-02 20:19:00  91.250  91.250  91.250  91.250
# ...                     ...     ...     ...     ...     ...
# 3883020 2022-12-30 16:53:00  80.407  80.407  80.367  80.392
# 3883021 2022-12-30 16:54:00  80.402  80.427  80.387  80.422
# 3883022 2022-12-30 16:55:00  80.417  80.447  80.402  80.407
# 3883023 2022-12-30 16:56:00  80.427  80.427  80.369  80.387
# 3883024 2022-12-30 16:57:00  80.367  80.432  80.367  80.432
#
#                      timestamp_ny             timestamp_utc  \
# 0       2011-01-02 20:15:00-05:00 2011-01-03 01:15:00+00:00
# 1       2011-01-02 20:16:00-05:00 2011-01-03 01:16:00+00:00
# 2       2011-01-02 20:17:00-05:00 2011-01-03 01:17:00+00:00
# 3       2011-01-02 20:18:00-05:00 2011-01-03 01:18:00+00:00
# 4       2011-01-02 20:19:00-05:00 2011-01-03 01:19:00+00:00
# ...                           ...                       ...
# 3883020 2022-12-30 16:53:00-05:00 2022-12-30 21:53:00+00:00
# 3883021 2022-12-30 16:54:00-05:00 2022-12-30 21:54:00+00:00
# 3883022 2022-12-30 16:55:00-05:00 2022-12-30 21:55:00+00:00
# 3883023 2022-12-30 16:56:00-05:00 2022-12-30 21:56:00+00:00
# 3883024 2022-12-30 16:57:00-05:00 2022-12-30 21:57:00+00:00
#
#         timestamp_utc_clean
# 0       2011-01-03 01:15:00
# 1       2011-01-03 01:16:00
# 2       2011-01-03 01:17:00
# 3       2011-01-03 01:18:00
# 4       2011-01-03 01:19:00
# ...                     ...
# 3883020 2022-12-30 21:53:00
# 3883021 2022-12-30 21:54:00
# 3883022 2022-12-30 21:55:00
# 3883023 2022-12-30 21:56:00
# 3883024 2022-12-30 21:57:00
#
# [3883025 rows x 8 columns]

# %%
wti_v2.dtypes
# Out:
# time                                     datetime64[us]
# open                                            float64
# high                                            float64
# low                                             float64
# close                                           float64
# timestamp_ny           datetime64[us, America/New_York]
# timestamp_utc                       datetime64[us, UTC]
# timestamp_utc_clean                      datetime64[us]
# dtype: object

# %%
wti_v2.to_csv(r"C:\Users\02_Florian_Benutzer\Desktop\trump_oil_analysis_v2\00_data\wti_v2.csv", sep=",", index=False, encoding="utf-8")
